# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# DISTRIBUCIÓN NORMAL

from scipy.stats import norm

def dnorm(x, mean=0, sd=1):
    """
    Función de densidad de probabilidad (PDF) de la normal.
    """
    result = norm.pdf(x, loc=mean, scale=sd)

    return result

def pnorm(q, mean=0, sd=1):
    """
    Función de distribución acumulada (CDF) de la normal.
    """
    result = norm.cdf(q, loc=mean, scale=sd)

    return result

def qnorm(p, mean=0, sd=1):
    """
    Función cuantil (percentil) de la normal.
    """
    result = norm.ppf(p, loc=mean, scale=sd)

    return result

def rnorm(n, mean=0, sd=1):
    """
    Genera n variables aleatorias normales.
    """
    result = norm.rvs(loc=mean, scale=sd, size=n)

    return result

# %%
print(dnorm(0, mean=0, sd=1))
print(pnorm(1, mean=0, sd=1))
print(pnorm(2, mean=0, sd=1))
print(qnorm(0.25, mean=0, sd=1))
print(qnorm(0.75, mean=0, sd=1))
print(rnorm(5, mean=0, sd=1))
# Out:
# 0.3989422804014327
# 0.8413447460685429
# 0.9772498680518208
# -0.6744897501960817
# 0.6744897501960817
# [-0.87798259 -0.82688035 -0.22647889  0.36736551  0.91358463]

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

mean = 0
sd = 1
x = np.linspace(-5, 5, 1000)
pdf = dnorm(x, mean=mean, sd=sd)
cdf = pnorm(x, mean=mean, sd=sd)
ppf = qnorm(np.linspace(0.01, 0.99, 1000), mean=mean, sd=sd)

fig, axis = plt.subplots(3, 1, figsize=(5, 7))

axis[0].plot(x, pdf)
axis[0].set_title("PDF - Normal")

axis[1].plot(x, cdf)
axis[1].set_title("CDF - Normal")

axis[2].plot(np.linspace(0.01, 0.99, 1000), ppf)
axis[2].set_title("PPF - Normal")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# DISTRIBUCIÓN UNIFORME

from scipy.stats import uniform

def dunif(x, min=0, max=1):
    """
    Función de densidad de probabilidad (PDF) uniforme.
    """
    result = uniform.pdf(x, loc=min, scale=max - min)

    return result

def punif(q, min=0, max=1):
    """
    Función de distribución acumulada (CDF) uniforme.
    """
    result = uniform.cdf(q, loc=min, scale=max - min)

    return result

def qunif(p, min=0, max=1):
    """
    Función cuantil de la uniforme.
    """
    result = uniform.ppf(p, loc=min, scale=max - min)

    return result

def runif(n, min=0, max=1):
    """
    Genera n variables aleatorias uniformes.
    """
    result = uniform.rvs(loc=min, scale=max - min, size=n)

    return result

# %%
print(dunif(0.5, min=0, max=1))
print(punif(0.7, min=0, max=1))
print(qunif(0.9, min=0, max=1))
print(runif(5, min=0, max=1))
# Out:
# 1.0
# 0.7
# 0.9
# [0.37454012 0.95071431 0.73199394 0.59865848 0.15601864]

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

a = 0
b = 1
x = np.linspace(-0.5, 1.5, 1000)
pdf = dunif(x, min=a, max=b)
cdf = punif(x, min=a, max=b)
ppf = qunif(np.linspace(0.01, 0.99, 1000), min=a, max=b)

fig, axis = plt.subplots(3, 1, figsize=(5, 7))

axis[0].plot(x, pdf)
axis[0].set_title("PDF - Uniforme")

axis[1].plot(x, cdf)
axis[1].set_title("CDF - Uniforme")

axis[2].plot(np.linspace(0.01, 0.99, 1000), ppf)
axis[2].set_title("PPF - Uniforme")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
